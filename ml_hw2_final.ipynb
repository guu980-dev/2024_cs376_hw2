# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/MyDrive/ml_hw2_repo"
# Out:
# /content/drive/MyDrive/ml_hw2_repo

# %%
# !git clone https://github.com/guu980-dev/torchdiffeq.git
# Out:
# Cloning into 'torchdiffeq'...
# remote: Enumerating objects: 1309, done.
# remote: Counting objects: 100% (460/460), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 1309 (delta 412), reused 388 (delta 375), pack-reused 849
# Receiving objects: 100% (1309/1309), 8.33 MiB | 17.97 MiB/s, done.
# Resolving deltas: 100% (807/807), done.

# %%
cd "/content/drive/MyDrive/ml_hw2_repo/torchdiffeq/examples"
# Out:
# /content/drive/MyDrive/ml_hw2_repo/torchdiffeq/examples

# %%
# !git pull origin master
# Out:
# From https://github.com/guu980-dev/torchdiffeq
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !pip install torchdiffeq
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
# Task 5: Train with adjoint=True

# !python odenet_mnist.py --network odenet --adjoint True
# Out:
# /content/drive/MyDrive/ml_hw2_repo/torchdiffeq/examples/odenet_mnist.py
# import os
# import argparse
# import logging
# import time
# import numpy as np
# import torch
# import torch.nn as nn
# from torch.utils.data import DataLoader
# import torchvision.datasets as datasets
# import torchvision.transforms as transforms
#
# parser = argparse.ArgumentParser()
# parser.add_argument('--network', type=str, choices=['resnet', 'odenet'], default='odenet')
# parser.add_argument('--tol', type=float, default=1e-3)
# parser.add_argument('--adjoint', type=eval, default=False, choices=[True, False])
# parser.add_argument('--downsampling-method', type=str, default='conv', choices=['conv', 'res'])
# parser.add_argument('--nepochs', type=int, default=160)
# parser.add_argument('--data_aug', type=eval, default=True, choices=[True, False])
# parser.add_argument('--lr', type=float, default=0.1)
# parser.add_argument('--batch_size', type=int, default=128)
# ...

# %%
# Task 6: Train with adjoint=True, ode solver=euler

# %run odenet_mnist_task6.py --solver_method euler --nepochs 11 --network odenet --adjoint True
# Out:
# Epoch 0000 | Time 0.203 (0.203) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.1125 | Test Acc 0.1134 | Average Wall Clock Time for batch in epoch 0.203 | Total Wall Clock Time in epoch 0.203 | batch number per epoch 0468
# Epoch 0001 | Time 0.355 (0.046) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.9646 | Test Acc 0.9687 | Average Wall Clock Time for batch in epoch 0.055 | Total Wall Clock Time in epoch 25.761 | batch number per epoch 0468
# Epoch 0002 | Time 0.202 (0.034) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.9753 | Test Acc 0.9793 | Average Wall Clock Time for batch in epoch 0.052 | Total Wall Clock Time in epoch 24.271 | batch number per epoch 0468
# Epoch 0003 | Time 0.208 (0.040) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.9853 | Test Acc 0.9844 | Average Wall Clock Time for batch in epoch 0.056 | Total Wall Clock Time in epoch 26.398 | batch number per epoch 0468
# ...

# %%
# Task 6: Train with adjoint=True, ode solver=rk4

# %run odenet_mnist_task6.py --solver_method rk4 --nepochs 11 --network odenet --adjoint True
# Out:
# Epoch 0000 | Time 0.202 (0.202) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.0974 | Test Acc 0.0954 | Average Wall Clock Time for batch in epoch 0.202 | Total Wall Clock Time in epoch 0.202 | batch number per epoch 0468
# Epoch 0001 | Time 0.254 (0.057) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.9823 | Test Acc 0.9848 | Average Wall Clock Time for batch in epoch 0.071 | Total Wall Clock Time in epoch 33.074 | batch number per epoch 0468
# Epoch 0002 | Time 0.337 (0.056) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.9850 | Test Acc 0.9866 | Average Wall Clock Time for batch in epoch 0.065 | Total Wall Clock Time in epoch 30.634 | batch number per epoch 0468
# Epoch 0003 | Time 0.317 (0.052) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.9919 | Test Acc 0.9906 | Average Wall Clock Time for batch in epoch 0.063 | Total Wall Clock Time in epoch 29.620 | batch number per epoch 0468
# ...

# %%
# Task 6: Train with adjoint=True, ode solver=dopri

# %run odenet_mnist_task6.py --solver_method dopri5 --nepochs 11 --network odenet --adjoint True
# Out:
# Epoch 0000 | Time 0.629 (0.629) | NFE-F 32.0 | NFE-B 38.0 | Train Acc 0.0975 | Test Acc 0.0974 | Average Wall Clock Time for batch in epoch 0.629 | Total Wall Clock Time in epoch 0.629 | batch number per epoch 0468
# Epoch 0001 | Time 0.527 (0.139) | NFE-F 20.3 | NFE-B 20.2 | Train Acc 0.9737 | Test Acc 0.9747 | Average Wall Clock Time for batch in epoch 0.161 | Total Wall Clock Time in epoch 75.304 | batch number per epoch 0468
# Epoch 0002 | Time 0.516 (0.129) | NFE-F 20.1 | NFE-B 20.0 | Train Acc 0.9821 | Test Acc 0.9841 | Average Wall Clock Time for batch in epoch 0.159 | Total Wall Clock Time in epoch 74.531 | batch number per epoch 0468
# Epoch 0003 | Time 0.343 (0.127) | NFE-F 20.1 | NFE-B 20.0 | Train Acc 0.9854 | Test Acc 0.9856 | Average Wall Clock Time for batch in epoch 0.156 | Total Wall Clock Time in epoch 73.034 | batch number per epoch 0468
# ...

# %%
# Task 6: Train with adjoint=False

# %run odenet_mnist_task6.py --nepochs 11 --network odenet --adjoint False
# Out:
# Epoch 0000 | Time 0.270 (0.270) | NFE-F 26.0 | NFE-B 0.0 | Train Acc 0.1306 | Test Acc 0.1346 | Average Wall Clock Time for batch in epoch 0.270 | Total Wall Clock Time in epoch 0.270 | batch number per epoch 0468
# Epoch 0001 | Time 0.419 (0.091) | NFE-F 20.2 | NFE-B 0.0 | Train Acc 0.9811 | Test Acc 0.9818 | Average Wall Clock Time for batch in epoch 0.118 | Total Wall Clock Time in epoch 55.075 | batch number per epoch 0468
# Epoch 0002 | Time 0.302 (0.088) | NFE-F 20.1 | NFE-B 0.0 | Train Acc 0.9883 | Test Acc 0.9887 | Average Wall Clock Time for batch in epoch 0.115 | Total Wall Clock Time in epoch 53.818 | batch number per epoch 0468
# Epoch 0003 | Time 0.469 (0.094) | NFE-F 20.1 | NFE-B 0.0 | Train Acc 0.9883 | Test Acc 0.9890 | Average Wall Clock Time for batch in epoch 0.119 | Total Wall Clock Time in epoch 55.589 | batch number per epoch 0468
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=False
(change model structure, drop out after fc, learning rate scheduler)
'''

# %run odenet_cifar10_task7.py --nepochs 11 --network odenet --adjoint False
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:01<00:00, 99146450.38it/s]
# Extracting .data/cifar10/cifar-10-python.tar.gz to .data/cifar10
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.728 (0.728) | NFE-F 32.0 | NFE-B 0.0 | Train Acc 0.0966 | Test Acc 0.0954 | Average Wall Clock Time for batch in epoch 0.728 | Total Wall Clock Time in epoch 0.728 | batch number per epoch 0390
# Epoch 0001 | Time 0.647 (0.146) | NFE-F 20.6 | NFE-B 0.0 | Train Acc 0.4079 | Test Acc 0.4104 | Average Wall Clock Time for batch in epoch 0.203 | Total Wall Clock Time in epoch 79.015 | batch number per epoch 0390
# Epoch 0002 | Time 0.434 (0.137) | NFE-F 20.3 | NFE-B 0.0 | Train Acc 0.5036 | Test Acc 0.4989 | Average Wall Clock Time for batch in epoch 0.189 | Total Wall Clock Time in epoch 73.522 | batch number per epoch 0390
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=True, ode solver=euler
(change model structure, drop out after fc, learning rate scheduler)
'''

# %run odenet_cifar10_task7.py --nepochs 11 --solver_method euler --network odenet --adjoint True
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.284 (0.284) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.1000 | Test Acc 0.1000 | Average Wall Clock Time for batch in epoch 0.284 | Total Wall Clock Time in epoch 0.284 | batch number per epoch 0390
# Epoch 0001 | Time 0.294 (0.085) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.3653 | Test Acc 0.3660 | Average Wall Clock Time for batch in epoch 0.113 | Total Wall Clock Time in epoch 44.241 | batch number per epoch 0390
# Epoch 0002 | Time 0.297 (0.067) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.4804 | Test Acc 0.4790 | Average Wall Clock Time for batch in epoch 0.108 | Total Wall Clock Time in epoch 42.144 | batch number per epoch 0390
# Epoch 0003 | Time 0.294 (0.083) | NFE-F 1.0 | NFE-B 1.0 | Train Acc 0.4864 | Test Acc 0.4851 | Average Wall Clock Time for batch in epoch 0.124 | Total Wall Clock Time in epoch 48.515 | batch number per epoch 0390
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=True, ode solver=rk4
(change model structure, drop out after fc, learning rate scheduler)
'''

# %run odenet_cifar10_task7.py --nepochs 11 --solver_method rk4 --network odenet --adjoint True
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.353 (0.353) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.1000 | Test Acc 0.1000 | Average Wall Clock Time for batch in epoch 0.353 | Total Wall Clock Time in epoch 0.353 | batch number per epoch 0390
# Epoch 0001 | Time 0.407 (0.099) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.4045 | Test Acc 0.4039 | Average Wall Clock Time for batch in epoch 0.140 | Total Wall Clock Time in epoch 54.693 | batch number per epoch 0390
# Epoch 0002 | Time 0.352 (0.087) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.4945 | Test Acc 0.4904 | Average Wall Clock Time for batch in epoch 0.137 | Total Wall Clock Time in epoch 53.435 | batch number per epoch 0390
# Epoch 0003 | Time 0.343 (0.087) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.5433 | Test Acc 0.5376 | Average Wall Clock Time for batch in epoch 0.126 | Total Wall Clock Time in epoch 49.160 | batch number per epoch 0390
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=True, ode solver=dopri
(change model structure, drop out after fc, learning rate scheduler)
'''

# %run odenet_cifar10_task7.py --nepochs 11 --network odenet --adjoint True
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.799 (0.799) | NFE-F 32.0 | NFE-B 38.0 | Train Acc 0.1129 | Test Acc 0.1126 | Average Wall Clock Time for batch in epoch 0.799 | Total Wall Clock Time in epoch 0.799 | batch number per epoch 0390
# Epoch 0001 | Time 0.571 (0.222) | NFE-F 20.6 | NFE-B 20.4 | Train Acc 0.4112 | Test Acc 0.4099 | Average Wall Clock Time for batch in epoch 0.279 | Total Wall Clock Time in epoch 108.743 | batch number per epoch 0390
# Epoch 0002 | Time 1.111 (0.226) | NFE-F 20.3 | NFE-B 20.0 | Train Acc 0.4729 | Test Acc 0.4638 | Average Wall Clock Time for batch in epoch 0.273 | Total Wall Clock Time in epoch 106.649 | batch number per epoch 0390
# Epoch 0003 | Time 0.696 (0.214) | NFE-F 20.2 | NFE-B 20.0 | Train Acc 0.5422 | Test Acc 0.5366 | Average Wall Clock Time for batch in epoch 0.268 | Total Wall Clock Time in epoch 104.580 | batch number per epoch 0390
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=True, ode solver=dopri
(change model structure, drop out after fc, learning rate scheduler)
+change optimizer SGD to adam
'''

# %run odenet_cifar10_adam.py --nepochs 11 --solver_method rk4 --network odenet --adjoint True
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.657 (0.657) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.1000 | Test Acc 0.1000 | Average Wall Clock Time for batch in epoch 0.657 | Total Wall Clock Time in epoch 0.657 | batch number per epoch 0390
# Epoch 0001 | Time 0.458 (0.097) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.2388 | Test Acc 0.2417 | Average Wall Clock Time for batch in epoch 0.125 | Total Wall Clock Time in epoch 48.631 | batch number per epoch 0390
# Epoch 0002 | Time 0.537 (0.081) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.2921 | Test Acc 0.2867 | Average Wall Clock Time for batch in epoch 0.126 | Total Wall Clock Time in epoch 49.160 | batch number per epoch 0390
# Epoch 0003 | Time 0.562 (0.089) | NFE-F 4.0 | NFE-B 4.0 | Train Acc 0.3227 | Test Acc 0.3269 | Average Wall Clock Time for batch in epoch 0.137 | Total Wall Clock Time in epoch 53.463 | batch number per epoch 0390
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=True, ode solver=dopri
(change model structure, drop out after fc, learning rate scheduler)
+change kernel number 64 to 128
'''

# %run odenet_cifar10_more_filter.py --nepochs 11 --network odenet --adjoint True
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:05<00:00, 28684982.37it/s]
# Extracting .data/cifar10/cifar-10-python.tar.gz to .data/cifar10
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 2.384 (2.384) | NFE-F 32.0 | NFE-B 38.0 | Train Acc 0.1000 | Test Acc 0.1000 | Average Wall Clock Time for batch in epoch 2.384 | Total Wall Clock Time in epoch 2.384 | batch number per epoch 0390
# Epoch 0001 | Time 0.561 (0.240) | NFE-F 14.7 | NFE-B 14.5 | Train Acc 0.3421 | Test Acc 0.3422 | Average Wall Clock Time for batch in epoch 0.279 | Total Wall Clock Time in epoch 108.637 | batch number per epoch 0390
# Epoch 0002 | Time 0.426 (0.201) | NFE-F 14.2 | NFE-B 14.0 | Train Acc 0.4429 | Test Acc 0.4447 | Average Wall Clock Time for batch in epoch 0.253 | Total Wall Clock Time in epoch 98.702 | batch number per epoch 0390
# ...

# %%
'''
Task 7: Train cifar-10 with adjoint=True, ode solver=dopri
(change model structure, drop out after fc, learning rate scheduler)
+change epochs 10 to 20
'''

# %run odenet_cifar10_task7.py --nepochs 21 --network odenet --adjoint True
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0000 | Time 0.878 (0.878) | NFE-F 32.0 | NFE-B 38.0 | Train Acc 0.1011 | Test Acc 0.1019 | Average Wall Clock Time for batch in epoch 0.878 | Total Wall Clock Time in epoch 0.878 | batch number per epoch 0390
# Epoch 0001 | Time 0.472 (0.207) | NFE-F 20.6 | NFE-B 21.8 | Train Acc 0.4072 | Test Acc 0.4090 | Average Wall Clock Time for batch in epoch 0.250 | Total Wall Clock Time in epoch 97.641 | batch number per epoch 0390
# Epoch 0002 | Time 0.426 (0.185) | NFE-F 20.3 | NFE-B 20.1 | Train Acc 0.5136 | Test Acc 0.5138 | Average Wall Clock Time for batch in epoch 0.228 | Total Wall Clock Time in epoch 88.726 | batch number per epoch 0390
# Epoch 0003 | Time 0.633 (0.194) | NFE-F 20.2 | NFE-B 20.0 | Train Acc 0.5395 | Test Acc 0.5350 | Average Wall Clock Time for batch in epoch 0.228 | Total Wall Clock Time in epoch 88.942 | batch number per epoch 0390
# ...
